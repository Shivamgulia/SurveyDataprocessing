# %%
# !pip install snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in /opt/anaconda3/lib/python3.12/site-packages (3.12.3)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (1.17.1)
# Requirement already satisfied: cryptography>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (43.0.0)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (24.2.1)
# Requirement already satisfied: pyjwt<3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2.8.0)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2024.1)
# Requirement already satisfied: requests<3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2.32.3)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2024.8.30)
# Requirement already satisfied: typing-extensions<5,>=4.3 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (4.11.0)
# Requirement already satisfied: filelock<4,>=3.5 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.13.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (3.10.0)
# Requirement already satisfied: tomlkit in /opt/anaconda3/lib/python3.12/site-packages (from snowflake-connector-python) (0.11.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0->snowflake-connector-python) (2.2.3)

# %%
import snowflake.connector

# %%
con = snowflake.connector.connect(
    user='shivamgulia',
    password='Ssjn.mrt10',
    account='adbcdzz-ro98064',
    warehouse='COMPUTE_WH',
    schema='SURVEYDATA',
    database='SURVEY'
)

# %%
cursor = con.cursor()

# %%
data = cursor.execute('SELECT * FROM CLEANEDDATA;').fetchall()

# %%
type(data)
# Out:
# list

# %%
columns = ['CUSTOMER', 'OVERALLSATISFACTION', 'FOODQUALITY', 'SPEEDSATISFACTION', 'ORDERACCURACY']

# %%
df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#        CUSTOMER OVERALLSATISFACTION FOODQUALITY SPEEDSATISFACTION  \
# 0             1               5.000       3.000             4.000
# 1             2               3.000       4.000             3.000
# 2             3               4.000       5.000             2.000
# 3             4               5.000       3.000             4.000
# 4             5               2.000       5.000             1.000
# ...         ...                 ...         ...               ...
# 10611     10612               4.000       2.000             3.000
# 10612     10613               3.000       3.000             3.000
# 10613     10614               5.000       3.000             3.000
# 10614     10615               3.000       3.000             3.000
# 10615     10616               1.000       3.000             3.000
#
#        ORDERACCURACY
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ...              ...
# 10611           True
# 10612           True
# 10613           True
# 10614           True
# 10615           True
#
# [10616 rows x 5 columns]

# %%
df.to_csv('cleaneddata.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data (replace 'your_data.csv' with the path to your CSV file)
# df = pd.read_csv('Customer-survey-data.csv')

# Drop any rows with missing values in relevant columns
df = df.dropna(subset=['FOODQUALITY', 'SPEEDSATISFACTION', 'OVERALLSATISFACTION'])

# Calculate correlations
correlation_matrix = df[['FOODQUALITY', 'SPEEDSATISFACTION', 'OVERALLSATISFACTION']].corr()

# %%
# Plot 2: Heatmap of correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix for Satisfaction Metrics")
plt.show()

# %%
count_columns = [1, 2, 3, 4, 5]
foodcount = df.groupby('FOODQUALITY').count()['CUSTOMER']
listfoodcount= foodcount.to_list()

# %%
plt.bar(count_columns, listfoodcount, color='skyblue')
plt.title('Food Quality Spread')
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
speed_count = df.groupby('SPEEDSATISFACTION').count()['CUSTOMER']
listspeedcount= speed_count.to_list()

# %%
# plt.bar(count_columns, listspeedcount, color='skyblue')
plt.plot(count_columns, listspeedcount, marker='o', color='b', linestyle='-', linewidth=2, markersize=5)
plt.title('Speed Rating Spread')
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
overall_count = df.groupby('OVERALLSATISFACTION').count()['CUSTOMER']
overallcountlist= overall_count.to_list()

# %%
# plt.bar(count_columns, overallcountlist, color='skyblue')
plt.pie(overallcountlist, labels=count_columns,  autopct='%1.1f%%', startangle=140)
plt.title('Overall Rating Spread')
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
accuracy_count = df.groupby('ORDERACCURACY').count()['CUSTOMER']
accuracycountlist= accuracy_count.to_list()

# %%
plt.bar(["No", "Yes"], accuracycountlist, color=['red', 'green'])
plt.title('Accuracy of Orders Spread')
plt.xlabel('Was Order Accurate')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
